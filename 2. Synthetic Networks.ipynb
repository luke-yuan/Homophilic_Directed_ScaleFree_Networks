# %%
__author__ = "Lisette Espin"
__copyright__ = "Copyright 2021, GESIS"
__credits__ = ["Lisette Espin-Noboa", 
               "Fariba Karimi",                
               "Claudia Wagner",
               "Markus Strohmaier"]
__license__ = "GPL"
__version__ = "1.0.1"
__maintainer__ = "Lisette Espin"
__email__ = "lisette.espin@gesis.org"
__status__ = "Development"

# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

from org.gesis.model.DPAH import DPAH
from org.gesis.model.DPA import DPA
from org.gesis.model.DH import DH
from org.gesis.model.Random import Random
from org.gesis.lib import viz
# Out:
# Bad key text.latex.preview in file /Users/Luke/miniforge3/envs/networks5/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /Users/Luke/miniforge3/envs/networks5/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# ...

# %% [markdown]
# <h2>Synthetic</h2>

# %%
# g = DPAH(N=2000, fm=0.5, d=0.001, plo_M=2.5, plo_m=2.5, h_MM=0.5, h_mm=0.5, verbose=True, seed=1)
g = DPA(N=2000, fm=0.5, d=0.001, plo_M=2.5, plo_m=2.5, verbose=True, seed=1)
#g = DH(N=2000, fm=0.5, d=0.001, plo_M=2.5, plo_m=2.5, h_MM=0.5, h_mm=0.5, verbose=True, seed=1)
#g = Random(N=100, fm=0.5, d=0.8, verbose=True, seed=1)
viz.plot_degree_powerlaw(g)
# Out:
# Directed Graph:
# N=2000 (M=1000, m=1000)
# E=3998 (d=0.001)
# Activity Power-Law outdegree: M=2.5, m=2.5
#
# 40->1888 (Mm): 1
# 1597->870 (mM): 2
# 1792->1368 (mm): 3
# 1227->538 (MM): 4
# 1586->1862 (mM): 5
# 63->532 (mm): 6
# 444->223 (mM): 7
# 1098->1987 (mm): 8
# 1581->1518 (mM): 9
# 1864->1250 (mM): 10
# 923->958 (mm): 11
# 1139->211 (mM): 12
# 923->1834 (mM): 13
# 905->1339 (mm): 14
# 1322->384 (Mm): 15
# 946->1799 (mm): 16
# 1381->1565 (MM): 17
# 75->198 (MM): 18
# 1218->1445 (Mm): 19
# 1108->551 (Mm): 20
# 936->793 (MM): 21
# 1242->1098 (Mm): 22
# 1573->1581 (Mm): 23
# 936->1108 (MM): 24
# 1153->1108 (MM): 25
# 1125->923 (Mm): 26
# 1579->1218 (MM): 27
# 4->1581 (mm): 28
# 1706->1579 (MM): 29
# 888->1792 (Mm): 30
# 1583->923 (Mm): 31
# 1956->1139 (Mm): 32
# 768->1792 (Mm): 33
# 916->1242 (MM): 34
# 977->923 (Mm): 35
# 412->1139 (mm): 36
# 572->946 (Mm): 37
# 1416->923 (mm): 38
# 1895->916 (mM): 39
# 1475->1322 (MM): 40
# 197->1956 (mM): 41
# 6->1108 (MM): 42
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 viz.plot_degree_powerlaw(g)
#
# NameError: name 'g' is not defined
